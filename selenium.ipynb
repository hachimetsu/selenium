# %%
from selenium import webdriver
from selenium.webdriver.common.by import By%
from selenium.webdriver.common.keys import Keys
import time
import random

# %%
options = webdriver.ChromeOptions()
options.add_argument("start-maximized")
options.add_argument("disable-infobars")
options.add_argument("--disable-extensions")

# Initialize the Chrome WebDriver
driver = webdriver.Chrome(options=options)
time.sleep(5)
driver.get("https://account.hoyoverse.com/?lang=en#/account/safetySettings")
time.sleep(100)
# Out:
# ---------------------------------------------------------------------------
# SessionNotCreatedException                Traceback (most recent call last)
# Cell In[2], line 8
#       4 options.add_argument("--disable-extensions")
#       7 # Initialize the Chrome WebDriver
# ----> 8 driver = webdriver.Chrome(options=options)
#       9 time.sleep(5)
#      10 driver.get("https://account.hoyoverse.com/?lang=en#/account/safetySettings")
#
# File /workspace/.pyenv_mirror/user/current/lib/python3.11/site-packages/selenium/webdriver/chrome/webdriver.py:45, in WebDriver.__init__(self, options, service, keep_alive)
#      42 service = service if service else Service()
#      43 options = options if options else Options()
# ---> 45 super().__init__(
#      46     DesiredCapabilities.CHROME["browserName"],
#      47     "goog",
#      48     options,
#      49     service,
#      50     keep_alive,
#      51 )
#
# File /workspace/.pyenv_mirror/user/current/lib/python3.11/site-packages/selenium/webdriver/chromium/webdriver.py:56, in ChromiumDriver.__init__(self, browser_name, vendor_prefix, options, service, keep_alive)
#      53 self.service.start()
#      55 try:
# ---> 56     super().__init__(
#      57         command_executor=ChromiumRemoteConnection(
#      58             remote_server_addr=self.service.service_url,
#      59             browser_name=browser_name,
#      60             vendor_prefix=vendor_prefix,
#      61             keep_alive=keep_alive,
#      62             ignore_proxy=options._ignore_local_proxy,
#      63         ),
#      64         options=options,
#      65     )
#      66 except Exception:
#      67     self.quit()
#
# File /workspace/.pyenv_mirror/user/current/lib/python3.11/site-packages/selenium/webdriver/remote/webdriver.py:205, in WebDriver.__init__(self, command_executor, keep_alive, file_detector, options)
#     203 self._authenticator_id = None
#     204 self.start_client()
# --> 205 self.start_session(capabilities)
#
# File /workspace/.pyenv_mirror/user/current/lib/python3.11/site-packages/selenium/webdriver/remote/webdriver.py:289, in WebDriver.start_session(self, capabilities)
#     282 """Creates a new session with the desired capabilities.
#     283
#     284 :Args:
#     285  - capabilities - a capabilities dict to start the session with.
#     286 """
#     288 caps = _create_caps(capabilities)
# --> 289 response = self.execute(Command.NEW_SESSION, caps)["value"]
#     290 self.session_id = response.get("sessionId")
#     291 self.caps = response.get("capabilities")
#
# File /workspace/.pyenv_mirror/user/current/lib/python3.11/site-packages/selenium/webdriver/remote/webdriver.py:344, in WebDriver.execute(self, driver_command, params)
#     342 response = self.command_executor.execute(driver_command, params)
#     343 if response:
# --> 344     self.error_handler.check_response(response)
#     345     response["value"] = self._unwrap_value(response.get("value", None))
#     346     return response
#
# File /workspace/.pyenv_mirror/user/current/lib/python3.11/site-packages/selenium/webdriver/remote/errorhandler.py:229, in ErrorHandler.check_response(self, response)
#     227         alert_text = value["alert"].get("text")
#     228     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 229 raise exception_class(message, screen, stacktrace)
#
# SessionNotCreatedException: Message: session not created: Chrome failed to start: exited normally.
#   (session not created: DevToolsActivePort file doesn't exist)
#   (The process started from chrome location /home/gitpod/.cache/selenium/chrome/linux64/117.0.5938.92/chrome is no longer running, so ChromeDriver is assuming that Chrome has crashed.)
# Stacktrace:
# #0 0x55d8ca1006b3 (/run/containerd/io.containerd.runtime.v2.task/k8s.io/cb2ab741e8ea6045cae1f84a1132d880210bbe4e275ed558fa573b37b43c6237/rootfs/home/gitpod/.cache/selenium/chromedriver/linux64/117.0.5938.92/chromedriver+0x71f6b2)
# #1 0x55d8c9dd61e7 (/run/containerd/io.containerd.runtime.v2.task/k8s.io/cb2ab741e8ea6045cae1f84a1132d880210bbe4e275ed558fa573b37b43c6237/rootfs/home/gitpod/.cache/selenium/chromedriver/linux64/117.0.5938.92/chromedriver+0x3f51e6)
# #2 0x55d8c9e09526 (/run/containerd/io.containerd.runtime.v2.task/k8s.io/cb2ab741e8ea6045cae1f84a1132d880210bbe4e275ed558fa573b37b43c6237/rootfs/home/gitpod/.cache/selenium/chromedriver/linux64/117.0.5938.92/chromedriver+0x428525)
# #3 0x55d8c9e0569c (/run/containerd/io.containerd.runtime.v2.task/k8s.io/cb2ab741e8ea6045cae1f84a1132d880210bbe4e275ed558fa573b37b43c6237/rootfs/home/gitpod/.cache/selenium/chromedriver/linux64/117.0.5938.92/chromedriver+0x42469b)
# #4 0x55d8c9e4823a (/run/containerd/io.containerd.runtime.v2.task/k8s.io/cb2ab741e8ea6045cae1f84a1132d880210bbe4e275ed558fa573b37b43c6237/rootfs/home/gitpod/.cache/selenium/chromedriver/linux64/117.0.5938.92/chromedriver+0x467239)
# #5 0x55d8c9e3ee93 (/run/containerd/io.containerd.runtime.v2.task/k8s.io/cb2ab741e8ea6045cae1f84a1132d880210bbe4e275ed558fa573b37b43c6237/rootfs/home/gitpod/.cache/selenium/chromedriver/linux64/117.0.5938.92/chromedriver+0x45de92)
# #6 0x55d8c9e11934 (/run/containerd/io.containerd.runtime.v2.task/k8s.io/cb2ab741e8ea6045cae1f84a1132d880210bbe4e275ed558fa573b37b43c6237/rootfs/home/gitpod/.cache/selenium/chromedriver/linux64/117.0.5938.92/chromedriver+0x430933)
# #7 0x55d8c9e1271e (/run/containerd/io.containerd.runtime.v2.task/k8s.io/cb2ab741e8ea6045cae1f84a1132d880210bbe4e275ed558fa573b37b43c6237/rootfs/home/gitpod/.cache/selenium/chromedriver/linux64/117.0.5938.92/chromedriver+0x43171d)
# #8 0x55d8ca0c5cb8 (/run/containerd/io.containerd.runtime.v2.task/k8s.io/cb2ab741e8ea6045cae1f84a1132d880210bbe4e275ed558fa573b37b43c6237/rootfs/home/gitpod/.cache/selenium/chromedriver/linux64/117.0.5938.92/chromedriver+0x6e4cb7)
# #9 0x55d8ca0c9bf0 (/run/containerd/io.containerd.runtime.v2.task/k8s.io/cb2ab741e8ea6045cae1f84a1132d880210bbe4e275ed558fa573b37b43c6237/rootfs/home/gitpod/.cache/selenium/chromedriver/linux64/117.0.5938.92/chromedriver+0x6e8bef)
# #10 0x55d8ca0d419c (/run/containerd/io.containerd.runtime.v2.task/k8s.io/cb2ab741e8ea6045cae1f84a1132d880210bbe4e275ed558fa573b37b43c6237/rootfs/home/gitpod/.cache/selenium/chromedriver/linux64/117.0.5938.92/chromedriver+0x6f319b)
# #11 0x55d8ca0ca808 (/run/containerd/io.containerd.runtime.v2.task/k8s.io/cb2ab741e8ea6045cae1f84a1132d880210bbe4e275ed558fa573b37b43c6237/rootfs/home/gitpod/.cache/selenium/chromedriver/linux64/117.0.5938.92/chromedriver+0x6e9807)
# #12 0x55d8ca09727f (/run/containerd/io.containerd.runtime.v2.task/k8s.io/cb2ab741e8ea6045cae1f84a1132d880210bbe4e275ed558fa573b37b43c6237/rootfs/home/gitpod/.cache/selenium/chromedriver/linux64/117.0.5938.92/chromedriver+0x6b627e)
# #13 0x55d8ca0eee88 (/run/containerd/io.containerd.runtime.v2.task/k8s.io/cb2ab741e8ea6045cae1f84a1132d880210bbe4e275ed558fa573b37b43c6237/rootfs/home/gitpod/.cache/selenium/chromedriver/linux64/117.0.5938.92/chromedriver+0x70de87)
# #14 0x55d8ca0ef059 (/run/containerd/io.containerd.runtime.v2.task/k8s.io/cb2ab741e8ea6045cae1f84a1132d880210bbe4e275ed558fa573b37b43c6237/rootfs/home/gitpod/.cache/selenium/chromedriver/linux64/117.0.5938.92/chromedriver+0x70e058)
# #15 0x55d8ca0ff843 (/run/containerd/io.containerd.runtime.v2.task/k8s.io/cb2ab741e8ea6045cae1f84a1132d880210bbe4e275ed558fa573b37b43c6237/rootfs/home/gitpod/.cache/selenium/chromedriver/linux64/117.0.5938.92/chromedriver+0x71e842)
# #16 0x7f07cf2a1b43 (/run/containerd/io.containerd.runtime.v2.task/k8s.io/cb2ab741e8ea6045cae1f84a1132d880210bbe4e275ed558fa573b37b43c6237/rootfs/usr/lib/x86_64-linux-gnu/libc.so.6+0x94b42)
